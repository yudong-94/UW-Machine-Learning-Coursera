# %%
import graphlab
people = graphlab.SFrame('people_wiki.gl/')
# Out:
# [INFO] 1452439767 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to /Users/hzdy1994/anaconda/lib/python2.7/site-packages/certifi/cacert.pem
# 1452439767 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to gracedongy@gmail.com and will expire on December 27, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-1970 - Server binary: /Users/hzdy1994/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1452439767.log
# [INFO] GraphLab Server Version: 1.7.1

# %%
elton = people[people['name'] == 'Elton John']
elton['word_count'] = graphlab.text_analytics.count_words(elton['text'])
elton[['word_count']].stack('word_count', new_column_name = ['word','count']).sort('count', ascending=False)
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 255
#
# Data:
# +-------+-------+
# |  word | count |
# +-------+-------+
# |  the  |   27  |
# |   in  |   18  |
# |  and  |   15  |
# |   of  |   13  |
# |   a   |   10  |
# |  has  |   9   |
# |  john |   7   |
# |   he  |   7   |
# |   on  |   6   |
# | award |   5   |
# +-------+-------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
people['word_count'] = graphlab.text_analytics.count_words(people['text'])
people['tfidf'] = graphlab.text_analytics.tf_idf(people['word_count'])
elton = people[people['name'] == 'Elton John']
elton[['tfidf']].stack('tfidf', new_column_name = ['word','tfidf']).sort('tfidf', ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 255
#
# Data:
# +---------------+---------------+
# |      word     |     tfidf     |
# +---------------+---------------+
# |    furnish    |  18.38947184  |
# |     elton     |  17.48232027  |
# |   billboard   | 17.3036809575 |
# |      john     | 13.9393127924 |
# |  songwriters  |  11.250406447 |
# | tonightcandle | 10.9864953892 |
# |  overallelton | 10.9864953892 |
# |    19702000   | 10.2933482087 |
# |   fivedecade  | 10.2933482087 |
# |      aids     |  10.262846934 |
# +---------------+---------------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
victoria = people[people['name'] == 'Victoria Beckham']
graphlab.distances.cosine(elton['tfidf'][0],victoria['tfidf'][0])
# Out:
# 0.9567006376655429

# %%
paul = people[people['name'] == 'Paul McCartney']
graphlab.distances.cosine(elton['tfidf'][0],paul['tfidf'][0])
# Out:
# 0.8250310029221779

# %%
knn_model = graphlab.nearest_neighbors.create(people,features=['tfidf'],label='name', distance='cosine')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %%
knn_model.query(elton)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 30.149ms     |
# PROGRESS: | Done         |         | 100         | 563.215ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+--------------------+------+
# | query_label | reference_label  |      distance      | rank |
# +-------------+------------------+--------------------+------+
# |      0      |    Elton John    | -2.22044604925e-16 |  1   |
# |      0      |   Rod Stewart    |   0.717219667893   |  2   |
# |      0      |  George Michael  |   0.747600998969   |  3   |
# ...

# %%
rwc_model = graphlab.nearest_neighbors.create(people,features=['word_count'],label='name', distance='cosine')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %%
rwc_model.query(elton)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 26.14ms      |
# PROGRESS: | Done         |         | 100         | 454.493ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-------------------+-------------------+------+
# | query_label |  reference_label  |      distance     | rank |
# +-------------+-------------------+-------------------+------+
# |      0      |     Elton John    | 2.22044604925e-16 |  1   |
# |      0      |   Cliff Richard   |   0.16142415259   |  2   |
# |      0      |   Sandro Petrone  |   0.16822542751   |  3   |
# ...

# %%
knn_model.query(victoria)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 24.779ms     |
# PROGRESS: | Done         |         | 100         | 553.782ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+---------------------+-------------------+------+
# | query_label |   reference_label   |      distance     | rank |
# +-------------+---------------------+-------------------+------+
# |      0      |   Victoria Beckham  | 1.11022302463e-16 |  1   |
# |      0      |    David Beckham    |   0.548169610263  |  2   |
# |      0      | Stephen Dow Beckham |   0.784986706828  |  3   |
# ...

# %%
rwc_model.query(victoria)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 20.347ms     |
# PROGRESS: | Done         |         | 100         | 444.065ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+--------------------------+--------------------+------+
# | query_label |     reference_label      |      distance      | rank |
# +-------------+--------------------------+--------------------+------+
# |      0      |     Victoria Beckham     | -2.22044604925e-16 |  1   |
# |      0      | Mary Fitzgerald (artist) |   0.207307036115   |  2   |
# |      0      |      Adrienne Corri      |   0.214509782788   |  3   |
# ...
